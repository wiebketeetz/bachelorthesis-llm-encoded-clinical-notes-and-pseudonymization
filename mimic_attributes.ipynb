# %%
import pandas as pd

# %%
admissions = pd.read_csv('/sc-resources/dh-mimic/mimic_iv_2_2/hosp/admissions.csv.gz')
patients = pd.read_csv('/sc-resources/dh-mimic/mimic_iv_2_2/hosp/patients.csv.gz')

# %%
#patients

# %%
#admissions

# %%
complete = pd.merge(admissions, patients, on = 'subject_id', how = 'left')

# %%
complete['gender'].value_counts()

# %%
complete['race'].value_counts()

# %%
complete['insurance'].value_counts()

# %%
complete['language'].value_counts()

# %%
complete['marital_status'].value_counts()
